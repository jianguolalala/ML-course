# %% [markdown]
# # Neural Networks
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. Please check the pdf file for more details.*
#
# In this exercise you will:
#
# - implement the **forward** and **backward** operations for different layers in neural networks
# - implement a simple neural networks for classification
#
# Please note that **YOU CANNOT USE ANY MACHINE LEARNING PACKAGE SUCH AS SKLEARN** for any homework, unless you are asked.

# %%
# some basic imports
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt
import math

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
# %load gradient_check.py
import scipy.io as sio
import numpy as np
from feedforward_backprop import feedforward_backprop
np.random.seed(1022)
digit_data = sio.loadmat('digit_data.mat')
X = digit_data['X']
y = digit_data['y']
_, num_cases = X.shape
train_num_cases = num_cases * 4 // 5
X = X.reshape((400, num_cases))
X = X.reshape((num_cases, 400))
# X has the shape of (number of samples, number of pixels)
train_data = X[:train_num_cases,:]
train_label = y[:, :train_num_cases]
test_data = X[train_num_cases:num_cases, :]
test_label = y[:,train_num_cases:]
weights = {}
weights['fully1_weight'] = np.random.randn(400, 25) / 400
weights['fully1_bias'] = np.random.rand(25, 1) 
weights['fully2_weight'] = np.random.randn(25, 10) / 25
weights['fully2_bias'] = np.random.rand(10, 1)

data = train_data[:100, :]
label = train_label[:, :100]

EPSILON = 0.00010
loss, _, grads = feedforward_backprop(data, label, weights)

# check correctness of fully1_bias's gradient
for c in range(weights['fully1_bias'].shape[0]):
    weights['fully1_bias'][c, 0] = weights['fully1_bias'][c, 0] + EPSILON
    loss_2, _, grads_2 = feedforward_backprop(data, label, weights)
    print('{:.2}, {:.2}, {:.2}'.format((loss_2 - loss) / EPSILON, 
                                       grads['fully1_bias_grad'][c, 0], 
                                       grads_2['fully1_bias_grad'][c, 0]))
    weights['fully1_bias'][c, 0] = weights['fully1_bias'][c, 0] - EPSILON
# Out:
# 0.0015, 0.0015, 0.0015
# 0.003, 0.003, 0.003
# -0.0012, -0.0012, -0.0012
# 0.0058, 0.0058, 0.0058
# -0.01, -0.01, -0.01
# -0.0041, -0.0041, -0.0041
# -0.0044, -0.0044, -0.0044
# -0.0017, -0.0017, -0.0017
# 0.0033, 0.0033, 0.0033
# 0.0058, 0.0058, 0.0058
# -0.0025, -0.0025, -0.0025
# 0.0016, 0.0016, 0.0016
# 0.0024, 0.0024, 0.0024
# -0.0041, -0.0041, -0.0041
# -0.012, -0.012, -0.012
# -0.0021, -0.0021, -0.0021
# 0.00039, 0.00039, 0.00039
# 0.0072, 0.0072, 0.0072
# 0.0054, 0.0054, 0.0054
# -0.005, -0.005, -0.005
# 0.0081, 0.0081, 0.0081
# 0.00099, 0.00099, 0.00099
# 0.0085, 0.0085, 0.0085
# 0.0051, 0.0051, 0.0051
# 0.0015, 0.0015, 0.0015

# %% [markdown]
# ## Training

# %%
digit_data = sio.loadmat('digit_data.mat')
X = digit_data['X']
y = digit_data['y']
_, num_cases = X.shape
train_num_cases = num_cases * 4 // 5
X = X.reshape((400, num_cases))
X = X.transpose()
# X has the shape of (number of samples, number of pixels)
train_data = X[:train_num_cases,:]
train_label = y[:, :train_num_cases]
test_data = X[train_num_cases:, :]
test_label = y[:, train_num_cases:]
weights = {}
weights['fully1_weight'] = np.random.randn(400, 25) / 400
weights['fully1_bias'] = np.random.rand(25, 1) 
weights['fully2_weight'] = np.random.randn(25, 10) / 25
weights['fully2_bias'] = np.random.rand(10, 1)

# %%
# training setting
weight_inc = {}
for name in ('fully1_weight', 'fully1_bias', 'fully2_weight', 'fully2_bias'):
    weight_inc[name] = np.zeros(weights[name].shape)
batch_size = 100
max_epoch = 10
momW = 0.9
wc = 0.0005
learning_rate = 0.1

# Training iterations
from get_new_weight_inc import get_new_weight_inc
from feedforward_backprop import feedforward_backprop

for epoch in range(max_epoch):
    for i in range(math.ceil(train_num_cases/batch_size)):
        data = train_data[i * batch_size:min((i + 1) * batch_size, train_num_cases), :]
        label = train_label[:, i * batch_size:min((i + 1) * batch_size, train_num_cases)]
        # The feedforward and backpropgation processes
        loss, accuracy, gradients = feedforward_backprop(data, label, weights)
        print('{:3}.{:2} loss:{:.3}, accuracy:{}'.format(epoch + 1, i + 1, loss, accuracy))
        # Updating weights
        for name in ('fully1_weight', 'fully1_bias', 'fully2_weight', 'fully2_bias'):
            weight_inc[name] = get_new_weight_inc(weight_inc[name], weights[name], momW, wc, learning_rate, gradients[name + '_grad'])
            weights[name] += weight_inc[name]
# Out:
#   1. 1 loss:2.31, accuracy:0.11
#   1. 2 loss:2.33, accuracy:0.11
#   1. 3 loss:2.29, accuracy:0.11
#   1. 4 loss:2.32, accuracy:0.1
#   1. 5 loss:2.28, accuracy:0.11
#   1. 6 loss:2.28, accuracy:0.1
#   1. 7 loss:2.28, accuracy:0.08
#   1. 8 loss:2.26, accuracy:0.35
#   1. 9 loss:2.24, accuracy:0.27
#   1.10 loss:2.23, accuracy:0.33
#   1.11 loss:2.19, accuracy:0.35
#   1.12 loss:2.15, accuracy:0.29
#   1.13 loss:2.14, accuracy:0.29
#   1.14 loss:2.12, accuracy:0.28
#   1.15 loss:2.01, accuracy:0.39
#   1.16 loss:1.92, accuracy:0.46
#   1.17 loss:1.87, accuracy:0.46
#   1.18 loss:1.79, accuracy:0.52
#   1.19 loss:1.77, accuracy:0.44
#   1.20 loss:1.63, accuracy:0.64
#   1.21 loss:1.49, accuracy:0.59
#   1.22 loss:1.43, accuracy:0.58
#   1.23 loss:1.26, accuracy:0.68
#   1.24 loss:1.12, accuracy:0.75
#   1.25 loss:1.07, accuracy:0.7
#   1.26 loss:0.994, accuracy:0.74
#   1.27 loss:1.08, accuracy:0.63
#   1.28 loss:0.896, accuracy:0.8
#   1.29 loss:0.842, accuracy:0.85
#   1.30 loss:0.829, accuracy:0.76
#   1.31 loss:0.789, accuracy:0.76
#   1.32 loss:0.842, accuracy:0.65
#   1.33 loss:0.681, accuracy:0.75
#   1.34 loss:0.712, accuracy:0.76
#   1.35 loss:0.81, accuracy:0.76
#   1.36 loss:0.724, accuracy:0.8
#   1.37 loss:0.572, accuracy:0.85
#   1.38 loss:0.614, accuracy:0.87
#   1.39 loss:0.6, accuracy:0.82
#   1.40 loss:0.67, accuracy:0.81
#   2. 1 loss:0.653, accuracy:0.72
#   2. 2 loss:0.585, accuracy:0.83
#   2. 3 loss:0.481, accuracy:0.85
#   2. 4 loss:0.638, accuracy:0.8
#   2. 5 loss:0.619, accuracy:0.77
#   2. 6 loss:0.378, accuracy:0.88
#   2. 7 loss:0.621, accuracy:0.82
#   2. 8 loss:0.426, accuracy:0.87
#   2. 9 loss:0.375, accuracy:0.88
#   2.10 loss:0.678, accuracy:0.82
#   2.11 loss:0.564, accuracy:0.8
#   2.12 loss:0.837, accuracy:0.83
#   2.13 loss:0.572, accuracy:0.78
#   2.14 loss:0.691, accuracy:0.77
#   2.15 loss:0.309, accuracy:0.9
#   2.16 loss:0.413, accuracy:0.86
#   2.17 loss:0.646, accuracy:0.77
#   2.18 loss:0.694, accuracy:0.81
#   2.19 loss:0.508, accuracy:0.84
#   2.20 loss:0.356, accuracy:0.9
#   2.21 loss:0.397, accuracy:0.86
#   2.22 loss:0.655, accuracy:0.84
#   2.23 loss:0.448, accuracy:0.83
#   2.24 loss:0.433, accuracy:0.83
#   2.25 loss:0.349, accuracy:0.91
#   2.26 loss:0.348, accuracy:0.92
#   2.27 loss:0.679, accuracy:0.79
#   2.28 loss:0.456, accuracy:0.9
#   2.29 loss:0.386, accuracy:0.86
#   2.30 loss:0.374, accuracy:0.87
#   2.31 loss:0.472, accuracy:0.89
#   2.32 loss:0.455, accuracy:0.84
#   2.33 loss:0.504, accuracy:0.87
#   2.34 loss:0.429, accuracy:0.86
#   2.35 loss:0.548, accuracy:0.84
#   2.36 loss:0.372, accuracy:0.9
#   2.37 loss:0.312, accuracy:0.89
#   2.38 loss:0.403, accuracy:0.9
#   2.39 loss:0.303, accuracy:0.93
#   2.40 loss:0.443, accuracy:0.89
#   3. 1 loss:0.275, accuracy:0.92
#   3. 2 loss:0.452, accuracy:0.89
#   3. 3 loss:0.247, accuracy:0.94
#   3. 4 loss:0.431, accuracy:0.9
#   3. 5 loss:0.345, accuracy:0.9
#   3. 6 loss:0.187, accuracy:0.97
#   3. 7 loss:0.391, accuracy:0.88
#   3. 8 loss:0.295, accuracy:0.95
#   3. 9 loss:0.189, accuracy:0.93
#   3.10 loss:0.382, accuracy:0.9
#   3.11 loss:0.305, accuracy:0.88
#   3.12 loss:0.542, accuracy:0.85
#   3.13 loss:0.401, accuracy:0.86
#   3.14 loss:0.499, accuracy:0.83
#   3.15 loss:0.217, accuracy:0.93
#   3.16 loss:0.283, accuracy:0.9
#   3.17 loss:0.348, accuracy:0.88
#   3.18 loss:0.518, accuracy:0.87
#   3.19 loss:0.493, accuracy:0.85
#   3.20 loss:0.302, accuracy:0.9
#   3.21 loss:0.312, accuracy:0.92
#   3.22 loss:0.363, accuracy:0.89
#   3.23 loss:0.32, accuracy:0.9
#   3.24 loss:0.31, accuracy:0.92
#   3.25 loss:0.223, accuracy:0.93
#   3.26 loss:0.261, accuracy:0.92
#   3.27 loss:0.445, accuracy:0.86
#   3.28 loss:0.283, accuracy:0.92
#   3.29 loss:0.29, accuracy:0.92
#   3.30 loss:0.239, accuracy:0.95
#   3.31 loss:0.356, accuracy:0.9
#   3.32 loss:0.244, accuracy:0.92
#   3.33 loss:0.306, accuracy:0.9
#   3.34 loss:0.301, accuracy:0.92
#   3.35 loss:0.425, accuracy:0.9
#   3.36 loss:0.314, accuracy:0.9
#   3.37 loss:0.263, accuracy:0.91
#   3.38 loss:0.291, accuracy:0.93
#   3.39 loss:0.275, accuracy:0.94
#   3.40 loss:0.442, accuracy:0.91
#   4. 1 loss:0.218, accuracy:0.94
#   4. 2 loss:0.328, accuracy:0.91
#   4. 3 loss:0.197, accuracy:0.95
#   4. 4 loss:0.321, accuracy:0.92
#   4. 5 loss:0.279, accuracy:0.92
#   4. 6 loss:0.141, accuracy:0.98
#   4. 7 loss:0.374, accuracy:0.9
#   4. 8 loss:0.23, accuracy:0.97
#   4. 9 loss:0.184, accuracy:0.96
#   4.10 loss:0.305, accuracy:0.9
#   4.11 loss:0.259, accuracy:0.9
#   4.12 loss:0.425, accuracy:0.89
#   4.13 loss:0.354, accuracy:0.87
#   4.14 loss:0.404, accuracy:0.89
#   4.15 loss:0.171, accuracy:0.93
#   4.16 loss:0.253, accuracy:0.93
#   4.17 loss:0.253, accuracy:0.92
#   4.18 loss:0.387, accuracy:0.88
#   4.19 loss:0.437, accuracy:0.86
#   4.20 loss:0.277, accuracy:0.92
#   4.21 loss:0.283, accuracy:0.91
#   4.22 loss:0.301, accuracy:0.89
#   4.23 loss:0.285, accuracy:0.9
#   4.24 loss:0.224, accuracy:0.93
#   4.25 loss:0.153, accuracy:0.96
#   4.26 loss:0.212, accuracy:0.94
#   4.27 loss:0.354, accuracy:0.89
#   4.28 loss:0.247, accuracy:0.94
#   4.29 loss:0.272, accuracy:0.92
#   4.30 loss:0.23, accuracy:0.93
#   4.31 loss:0.261, accuracy:0.92
#   4.32 loss:0.211, accuracy:0.93
#   4.33 loss:0.273, accuracy:0.91
#   4.34 loss:0.259, accuracy:0.92
#   4.35 loss:0.376, accuracy:0.91
#   4.36 loss:0.287, accuracy:0.92
#   4.37 loss:0.212, accuracy:0.93
#   4.38 loss:0.274, accuracy:0.94
#   4.39 loss:0.236, accuracy:0.94
#   4.40 loss:0.374, accuracy:0.92
#   5. 1 loss:0.174, accuracy:0.95
#   5. 2 loss:0.289, accuracy:0.91
#   5. 3 loss:0.178, accuracy:0.96
#   5. 4 loss:0.268, accuracy:0.92
#   5. 5 loss:0.265, accuracy:0.92
#   5. 6 loss:0.115, accuracy:0.99
#   5. 7 loss:0.321, accuracy:0.9
#   5. 8 loss:0.166, accuracy:0.98
#   5. 9 loss:0.162, accuracy:0.97
#   5.10 loss:0.274, accuracy:0.9
#   5.11 loss:0.245, accuracy:0.89
#   5.12 loss:0.348, accuracy:0.93
#   5.13 loss:0.319, accuracy:0.91
#   5.14 loss:0.353, accuracy:0.91
#   5.15 loss:0.137, accuracy:0.94
#   5.16 loss:0.227, accuracy:0.95
#   5.17 loss:0.227, accuracy:0.93
#   5.18 loss:0.313, accuracy:0.92
#   5.19 loss:0.375, accuracy:0.87
#   5.20 loss:0.243, accuracy:0.93
#   5.21 loss:0.233, accuracy:0.93
#   5.22 loss:0.248, accuracy:0.91
#   5.23 loss:0.26, accuracy:0.93
#   5.24 loss:0.191, accuracy:0.92
#   5.25 loss:0.135, accuracy:0.97
#   5.26 loss:0.177, accuracy:0.95
#   5.27 loss:0.303, accuracy:0.89
#   5.28 loss:0.213, accuracy:0.94
#   5.29 loss:0.251, accuracy:0.95
#   5.30 loss:0.212, accuracy:0.94
#   5.31 loss:0.216, accuracy:0.95
#   5.32 loss:0.2, accuracy:0.96
#   5.33 loss:0.264, accuracy:0.93
#   5.34 loss:0.253, accuracy:0.93
#   5.35 loss:0.357, accuracy:0.92
#   5.36 loss:0.24, accuracy:0.94
#   5.37 loss:0.174, accuracy:0.95
#   5.38 loss:0.25, accuracy:0.94
#   5.39 loss:0.204, accuracy:0.94
#   5.40 loss:0.316, accuracy:0.93
#   6. 1 loss:0.145, accuracy:0.95
#   6. 2 loss:0.242, accuracy:0.91
#   6. 3 loss:0.156, accuracy:0.96
#   6. 4 loss:0.225, accuracy:0.96
#   6. 5 loss:0.264, accuracy:0.92
#   6. 6 loss:0.127, accuracy:0.98
#   6. 7 loss:0.284, accuracy:0.92
#   6. 8 loss:0.14, accuracy:0.97
#   6. 9 loss:0.122, accuracy:0.97
#   6.10 loss:0.206, accuracy:0.95
#   6.11 loss:0.208, accuracy:0.93
#   6.12 loss:0.29, accuracy:0.93
#   6.13 loss:0.266, accuracy:0.93
#   6.14 loss:0.325, accuracy:0.92
#   6.15 loss:0.106, accuracy:0.96
#   6.16 loss:0.195, accuracy:0.97
#   6.17 loss:0.194, accuracy:0.93
#   6.18 loss:0.265, accuracy:0.93
#   6.19 loss:0.311, accuracy:0.91
#   6.20 loss:0.192, accuracy:0.93
#   6.21 loss:0.198, accuracy:0.94
#   6.22 loss:0.193, accuracy:0.92
#   6.23 loss:0.207, accuracy:0.95
#   6.24 loss:0.161, accuracy:0.93
#   6.25 loss:0.122, accuracy:0.97
#   6.26 loss:0.153, accuracy:0.95
#   6.27 loss:0.284, accuracy:0.89
#   6.28 loss:0.197, accuracy:0.97
#   6.29 loss:0.234, accuracy:0.94
#   6.30 loss:0.175, accuracy:0.96
#   6.31 loss:0.179, accuracy:0.95
#   6.32 loss:0.169, accuracy:0.96
#   6.33 loss:0.239, accuracy:0.93
#   6.34 loss:0.238, accuracy:0.94
#   6.35 loss:0.336, accuracy:0.92
#   6.36 loss:0.196, accuracy:0.94
#   6.37 loss:0.166, accuracy:0.93
#   6.38 loss:0.214, accuracy:0.93
#   6.39 loss:0.188, accuracy:0.94
#   6.40 loss:0.283, accuracy:0.93
#   7. 1 loss:0.133, accuracy:0.95
#   7. 2 loss:0.181, accuracy:0.95
#   7. 3 loss:0.128, accuracy:0.98
#   7. 4 loss:0.187, accuracy:0.96
#   7. 5 loss:0.23, accuracy:0.93
#   7. 6 loss:0.116, accuracy:0.99
#   7. 7 loss:0.265, accuracy:0.92
#   7. 8 loss:0.127, accuracy:0.97
#   7. 9 loss:0.11, accuracy:0.96
#   7.10 loss:0.159, accuracy:0.95
#   7.11 loss:0.165, accuracy:0.92
#   7.12 loss:0.244, accuracy:0.96
#   7.13 loss:0.205, accuracy:0.94
#   7.14 loss:0.286, accuracy:0.92
#   7.15 loss:0.0857, accuracy:0.97
#   7.16 loss:0.161, accuracy:0.97
#   7.17 loss:0.154, accuracy:0.95
#   7.18 loss:0.234, accuracy:0.94
#   7.19 loss:0.28, accuracy:0.9
#   7.20 loss:0.162, accuracy:0.93
#   7.21 loss:0.188, accuracy:0.94
#   7.22 loss:0.168, accuracy:0.94
#   7.23 loss:0.17, accuracy:0.97
#   7.24 loss:0.132, accuracy:0.95
#   7.25 loss:0.102, accuracy:0.98
#   7.26 loss:0.132, accuracy:0.96
#   7.27 loss:0.255, accuracy:0.93
#   7.28 loss:0.175, accuracy:0.96
#   7.29 loss:0.224, accuracy:0.93
#   7.30 loss:0.169, accuracy:0.96
#   7.31 loss:0.177, accuracy:0.95
#   7.32 loss:0.137, accuracy:0.96
#   7.33 loss:0.196, accuracy:0.95
#   7.34 loss:0.215, accuracy:0.94
#   7.35 loss:0.301, accuracy:0.92
#   7.36 loss:0.172, accuracy:0.94
#   7.37 loss:0.147, accuracy:0.94
#   7.38 loss:0.173, accuracy:0.95
#   7.39 loss:0.173, accuracy:0.96
#   7.40 loss:0.277, accuracy:0.93
#   8. 1 loss:0.126, accuracy:0.95
#   8. 2 loss:0.159, accuracy:0.95
#   8. 3 loss:0.115, accuracy:0.98
#   8. 4 loss:0.175, accuracy:0.96
#   8. 5 loss:0.185, accuracy:0.96
#   8. 6 loss:0.105, accuracy:0.99
#   8. 7 loss:0.259, accuracy:0.9
#   8. 8 loss:0.127, accuracy:0.97
#   8. 9 loss:0.104, accuracy:0.98
#   8.10 loss:0.146, accuracy:0.95
#   8.11 loss:0.149, accuracy:0.93
#   8.12 loss:0.226, accuracy:0.96
#   8.13 loss:0.173, accuracy:0.96
#   8.14 loss:0.241, accuracy:0.94
#   8.15 loss:0.0848, accuracy:0.96
#   8.16 loss:0.156, accuracy:0.96
#   8.17 loss:0.142, accuracy:0.95
#   8.18 loss:0.206, accuracy:0.95
#   8.19 loss:0.245, accuracy:0.92
#   8.20 loss:0.159, accuracy:0.93
#   8.21 loss:0.172, accuracy:0.94
#   8.22 loss:0.147, accuracy:0.96
#   8.23 loss:0.146, accuracy:0.97
#   8.24 loss:0.122, accuracy:0.96
#   8.25 loss:0.0959, accuracy:0.98
#   8.26 loss:0.113, accuracy:0.98
#   8.27 loss:0.205, accuracy:0.95
#   8.28 loss:0.168, accuracy:0.95
#   8.29 loss:0.22, accuracy:0.93
#   8.30 loss:0.155, accuracy:0.96
#   8.31 loss:0.156, accuracy:0.95
#   8.32 loss:0.109, accuracy:0.97
#   8.33 loss:0.184, accuracy:0.96
#   8.34 loss:0.193, accuracy:0.95
#   8.35 loss:0.268, accuracy:0.94
#   8.36 loss:0.156, accuracy:0.95
#   8.37 loss:0.14, accuracy:0.95
#   8.38 loss:0.14, accuracy:0.98
#   8.39 loss:0.156, accuracy:0.96
#   8.40 loss:0.233, accuracy:0.94
#   9. 1 loss:0.0945, accuracy:0.99
#   9. 2 loss:0.152, accuracy:0.95
#   9. 3 loss:0.112, accuracy:0.97
#   9. 4 loss:0.16, accuracy:0.96
#   9. 5 loss:0.165, accuracy:0.95
#   9. 6 loss:0.0778, accuracy:0.99
#   9. 7 loss:0.2, accuracy:0.93
#   9. 8 loss:0.0938, accuracy:0.99
#   9. 9 loss:0.104, accuracy:0.96
#   9.10 loss:0.154, accuracy:0.95
#   9.11 loss:0.126, accuracy:0.95
#   9.12 loss:0.212, accuracy:0.96
#   9.13 loss:0.149, accuracy:0.95
#   9.14 loss:0.201, accuracy:0.95
#   9.15 loss:0.0684, accuracy:0.98
#   9.16 loss:0.153, accuracy:0.94
#   9.17 loss:0.168, accuracy:0.95
#   9.18 loss:0.209, accuracy:0.94
#   9.19 loss:0.216, accuracy:0.93
#   9.20 loss:0.146, accuracy:0.94
#   9.21 loss:0.137, accuracy:0.95
#   9.22 loss:0.133, accuracy:0.94
#   9.23 loss:0.131, accuracy:0.97
#   9.24 loss:0.129, accuracy:0.97
#   9.25 loss:0.108, accuracy:0.96
#   9.26 loss:0.102, accuracy:0.98
#   9.27 loss:0.172, accuracy:0.95
#   9.28 loss:0.143, accuracy:0.97
#   9.29 loss:0.205, accuracy:0.94
#   9.30 loss:0.151, accuracy:0.97
#   9.31 loss:0.155, accuracy:0.95
#   9.32 loss:0.101, accuracy:0.97
#   9.33 loss:0.184, accuracy:0.96
#   9.34 loss:0.172, accuracy:0.95
#   9.35 loss:0.243, accuracy:0.95
#   9.36 loss:0.138, accuracy:0.96
#   9.37 loss:0.145, accuracy:0.95
#   9.38 loss:0.133, accuracy:0.98
#   9.39 loss:0.146, accuracy:0.96
#   9.40 loss:0.195, accuracy:0.93
#  10. 1 loss:0.0799, accuracy:0.98
#  10. 2 loss:0.136, accuracy:0.95
#  10. 3 loss:0.0973, accuracy:0.98
#  10. 4 loss:0.146, accuracy:0.97
#  10. 5 loss:0.163, accuracy:0.95
#  10. 6 loss:0.0683, accuracy:0.99
#  10. 7 loss:0.161, accuracy:0.95
#  10. 8 loss:0.0728, accuracy:0.98
#  10. 9 loss:0.0861, accuracy:0.97
#  10.10 loss:0.128, accuracy:0.95
#  10.11 loss:0.106, accuracy:0.96
#  10.12 loss:0.19, accuracy:0.97
#  10.13 loss:0.16, accuracy:0.95
#  10.14 loss:0.181, accuracy:0.97
#  10.15 loss:0.0497, accuracy:0.99
#  10.16 loss:0.12, accuracy:0.96
#  10.17 loss:0.163, accuracy:0.95
#  10.18 loss:0.213, accuracy:0.93
#  10.19 loss:0.2, accuracy:0.92
#  10.20 loss:0.129, accuracy:0.95
#  10.21 loss:0.112, accuracy:0.97
#  10.22 loss:0.111, accuracy:0.96
#  10.23 loss:0.113, accuracy:0.98
#  10.24 loss:0.124, accuracy:0.96
#  10.25 loss:0.123, accuracy:0.96
#  10.26 loss:0.0949, accuracy:0.98
#  10.27 loss:0.156, accuracy:0.96
#  10.28 loss:0.119, accuracy:0.97
#  10.29 loss:0.163, accuracy:0.95
#  10.30 loss:0.112, accuracy:0.97
#  10.31 loss:0.139, accuracy:0.95
#  10.32 loss:0.0904, accuracy:0.97
#  10.33 loss:0.188, accuracy:0.95
#  10.34 loss:0.161, accuracy:0.94
#  10.35 loss:0.224, accuracy:0.96
#  10.36 loss:0.118, accuracy:0.95
#  10.37 loss:0.122, accuracy:0.96
#  10.38 loss:0.124, accuracy:0.98
#  10.39 loss:0.123, accuracy:0.97
#  10.40 loss:0.166, accuracy:0.95

# %% [markdown]
# ## Testing

# %%
# TODO
loss, accuracy, _ = feedforward_backprop(test_data, test_label, weights)
print('loss:{:.3}, accuracy:{}'.format(loss, accuracy))
# Out:
# loss:0.246, accuracy:0.924
